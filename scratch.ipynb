# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry


def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    status_forcelist=(500, 502, 504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

res = requests_retry_session().get('https://min-api.cryptocompare.com/data/histohour?fsym=MAID&tsym=BTC&limit=80&e=CCCAGG')
res.json()
# Out:
# {'Aggregated': False,
#  'ConversionType': {'conversionSymbol': '', 'type': 'direct'},
#  'Data': [{'close': 6.816e-05,
#    'high': 6.93e-05,
#    'low': 6.797e-05,
#    'open': 6.896e-05,
#    'time': 1514757600,
#    'volumefrom': 168491.32,
#    'volumeto': 11.49},
#   {'close': 6.807e-05,
#    'high': 6.834e-05,
#    'low': 6.736e-05,
#    'open': 6.82e-05,
#    'time': 1514761200,
#    'volumefrom': 183586.14,
#    'volumeto': 12.25},
#   {'close': 6.736e-05,
#    'high': 6.861e-05,
#    'low': 6.726e-05,
#    'open': 6.841e-05,
#    'time': 1514764800,
#    'volumefrom': 285998.58,
#    'volumeto': 19.39},
#   {'close': 6.726e-05,
#    'high': 6.835e-05,
#    'low': 6.615e-05,
#    'open': 6.736e-05,
#    'time': 1514768400,
#    'volumefrom': 175542.28,
#    'volumeto': 11.81},
#   {'close': 6.873e-05,
#    'high': 6.967e-05,
#    'low': 6.704e-05,
#    'open': 6.727e-05,
#    'time': 1514772000,
#    'volumefrom': 197999.2,
#    'volumeto': 13.61},
#   {'close': 7.021e-05,
#    'high': 7.028e-05,
#    'low': 6.858e-05,
#    'open': 6.873e-05,
#    'time': 1514775600,
#    'volumefrom': 160495.08,
#    'volumeto': 11.18},
#   {'close': 7.099e-05,
#    'high': 7.099e-05,
#    'low': 6.947e-05,
#    'open': 7.019e-05,
#    'time': 1514779200,
#    'volumefrom': 246951.97,
#    'volumeto': 17.59},
#   {'close': 7.387e-05,
#    'high': 7.451e-05,
#    'low': 7.057e-05,
#    'open': 7.101e-05,
#    'time': 1514782800,
#    'volumefrom': 879656.79,
#    'volumeto': 64.65},
#   {'close': 7.623e-05,
#    'high': 7.901e-05,
#    'low': 7.363e-05,
#    'open': 7.395e-05,
#    'time': 1514786400,
#    'volumefrom': 1872263.92,
#    'volumeto': 144.7},
#   {'close': 7.578e-05,
#    'high': 7.774e-05,
#    'low': 7.459e-05,
#    'open': 7.618e-05,
#    'time': 1514790000,
#    'volumefrom': 686572.13,
#    'volumeto': 52.35},
#   {'close': 7.433e-05,
#    'high': 7.602e-05,
#    'low': 7.404e-05,
#    'open': 7.571e-05,
#    'time': 1514793600,
#    'volumefrom': 362870.2,
#    'volumeto': 26.98},
#   {'close': 8.148e-05,
#    'high': 8.33e-05,
#    'low': 7.438e-05,
#    'open': 7.451e-05,
#    'time': 1514797200,
#    'volumefrom': 2175810.48,
#    'volumeto': 176.86},
#   {'close': 8.552e-05,
#    'high': 8.725e-05,
#    'low': 8.17e-05,
#    'open': 8.204e-05,
#    'time': 1514800800,
#    'volumefrom': 2349650.72,
#    'volumeto': 202.78},
#   {'close': 8.498e-05,
#    'high': 8.578e-05,
#    'low': 8.207e-05,
#    'open': 8.554e-05,
#    'time': 1514804400,
#    'volumefrom': 1427575.07,
#    'volumeto': 119.7},
#   {'close': 8.861e-05,
#    'high': 8.863e-05,
#    'low': 8.405e-05,
#    'open': 8.497e-05,
#    'time': 1514808000,
#    'volumefrom': 895540.72,
#    'volumeto': 77.66},
#   {'close': 8.434e-05,
#    'high': 8.868e-05,
#    'low': 8.308e-05,
#    'open': 8.862e-05,
#    'time': 1514811600,
#    'volumefrom': 1066387.43,
#    'volumeto': 91.59},
#   {'close': 8.132e-05,
#    'high': 8.424e-05,
#    'low': 7.985e-05,
#    'open': 8.401e-05,
#    'time': 1514815200,
#    'volumefrom': 994024.65,
#    'volumeto': 80.96},
#   {'close': 8.188e-05,
#    'high': 8.213e-05,
#    'low': 7.981e-05,
#    'open': 8.122e-05,
#    'time': 1514818800,
#    'volumefrom': 653367.87,
#    'volumeto': 52.72},
#   {'close': 8.22e-05,
#    'high': 8.387e-05,
#    'low': 8.126e-05,
#    'open': 8.19e-05,
#    'time': 1514822400,
#    'volumefrom': 431596.55,
#    'volumeto': 35.71},
#   {'close': 8.615e-05,
#    'high': 8.729e-05,
#    'low': 8.141e-05,
#    'open': 8.22e-05,
#    'time': 1514826000,
#    'volumefrom': 696759.83,
#    'volumeto': 58.91},
#   {'close': 8.443e-05,
#    'high': 8.697e-05,
#    'low': 8.359e-05,
#    'open': 8.617e-05,
#    'time': 1514829600,
#    'volumefrom': 677573.3,
#    'volumeto': 57.5},
#   {'close': 8.596e-05,
#    'high': 8.663e-05,
#    'low': 8.351e-05,
#    'open': 8.412e-05,
#    'time': 1514833200,
#    'volumefrom': 458317.77,
#    'volumeto': 38.91},
#   {'close': 8.418e-05,
#    'high': 8.607e-05,
#    'low': 8.368e-05,
#    'open': 8.605e-05,
#    'time': 1514836800,
#    'volumefrom': 371350.22,
#    'volumeto': 31.07},
#   {'close': 8.312e-05,
#    'high': 8.442e-05,
#    'low': 7.975e-05,
#    'open': 8.419e-05,
#    'time': 1514840400,
#    'volumefrom': 801892.53,
#    'volumeto': 66},
#   {'close': 8.343e-05,
#    'high': 8.361e-05,
#    'low': 8.166e-05,
#    'open': 8.315e-05,
#    'time': 1514844000,
#    'volumefrom': 456982.7,
#    'volumeto': 37.74},
#   {'close': 8.231e-05,
#    'high': 8.486e-05,
#    'low': 8.198e-05,
#    'open': 8.362e-05,
#    'time': 1514847600,
#    'volumefrom': 362994.7,
#    'volumeto': 30},
#   {'close': 8.032e-05,
#    'high': 8.248e-05,
#    'low': 7.924e-05,
#    'open': 8.214e-05,
#    'time': 1514851200,
#    'volumefrom': 694269.98,
#    'volumeto': 55.42},
#   {'close': 8.044e-05,
#    'high': 8.246e-05,
#    'low': 8.025e-05,
#    'open': 8.046e-05,
#    'time': 1514854800,
#    'volumefrom': 243638.89,
#    'volumeto': 19.49},
#   {'close': 8.528e-05,
#    'high': 8.528e-05,
#    'low': 8.041e-05,
#    'open': 8.081e-05,
#    'time': 1514858400,
#    'volumefrom': 747188.33,
#    'volumeto': 62.38},
#   {'close': 8.553e-05,
#    'high': 8.658e-05,
#    'low': 8.447e-05,
#    'open': 8.549e-05,
#    'time': 1514862000,
#    'volumefrom': 568981,
#    'volumeto': 48.49},
#   {'close': 8.489e-05,
#    'high': 8.613e-05,
#    'low': 8.457e-05,
#    'open': 8.555e-05,
#    'time': 1514865600,
#    'volumefrom': 401362.08,
#    'volumeto': 34.08},
#   {'close': 8.558e-05,
#    'high': 8.591e-05,
#    'low': 8.469e-05,
#    'open': 8.491e-05,
#    'time': 1514869200,
#    'volumefrom': 256036.9,
#    'volumeto': 21.74},
#   {'close': 8.513e-05,
#    'high': 8.566e-05,
#    'low': 8.469e-05,
#    'open': 8.562e-05,
#    'time': 1514872800,
#    'volumefrom': 280560.83,
#    'volumeto': 23.79},
#   {'close': 8.471e-05,
#    'high': 8.513e-05,
#    'low': 8.425e-05,
#    'open': 8.513e-05,
#    'time': 1514876400,
#    'volumefrom': 425780.66,
#    'volumeto': 35.83},
#   {'close': 8.474e-05,
#    'high': 8.537e-05,
#    'low': 8.444e-05,
#    'open': 8.471e-05,
#    'time': 1514880000,
#    'volumefrom': 259131.31,
#    'volumeto': 21.9},
#   {'close': 8.563e-05,
#    'high': 8.655e-05,
#    'low': 8.464e-05,
#    'open': 8.473e-05,
#    'time': 1514883600,
#    'volumefrom': 242456.14,
#    'volumeto': 20.68},
#   {'close': 8.588e-05,
#    'high': 8.653e-05,
#    'low': 8.537e-05,
#    'open': 8.568e-05,
#    'time': 1514887200,
#    'volumefrom': 157129.28,
#    'volumeto': 13.39},
#   {'close': 8.529e-05,
#    'high': 8.691e-05,
#    'low': 8.522e-05,
#    'open': 8.575e-05,
#    'time': 1514890800,
#    'volumefrom': 318507.76,
#    'volumeto': 27.34},
#   {'close': 8.652e-05,
#    'high': 8.653e-05,
#    'low': 8.447e-05,
#    'open': 8.528e-05,
#    'time': 1514894400,
#    'volumefrom': 419018.56,
#    'volumeto': 35.79},
#   {'close': 8.501e-05,
#    'high': 8.677e-05,
#    'low': 8.47e-05,
#    'open': 8.656e-05,
#    'time': 1514898000,
#    'volumefrom': 394233.94,
#    'volumeto': 33.74},
#   {'close': 8.482e-05,
#    'high': 8.5e-05,
#    'low': 8.427e-05,
#    'open': 8.5e-05,
#    'time': 1514901600,
#    'volumefrom': 243752.46,
#    'volumeto': 20.63},
#   {'close': 8.399e-05,
#    'high': 8.483e-05,
#    'low': 8.377e-05,
#    'open': 8.481e-05,
#    'time': 1514905200,
#    'volumefrom': 193737.46,
#    'volumeto': 16.26},
#   {'close': 8.41e-05,
#    'high': 8.538e-05,
#    'low': 8.316e-05,
#    'open': 8.394e-05,
#    'time': 1514908800,
#    'volumefrom': 545560.7,
#    'volumeto': 46.03},
#   {'close': 8.51e-05,
#    'high': 8.532e-05,
#    'low': 8.349e-05,
#    'open': 8.408e-05,
#    'time': 1514912400,
#    'volumefrom': 275064.82,
#    'volumeto': 23.15},
#   {'close': 7.68e-05,
#    'high': 8.531e-05,
#    'low': 7.549e-05,
#    'open': 8.511e-05,
#    'time': 1514916000,
#    'volumefrom': 1789368.45,
#    'volumeto': 142.03},
#   {'close': 7.381e-05,
#    'high': 7.81e-05,
#    'low': 7.233e-05,
#    'open': 7.702e-05,
#    'time': 1514919600,
#    'volumefrom': 1387017.91,
#    'volumeto': 103.39},
#   {'close': 7.403e-05,
#    'high': 7.558e-05,
#    'low': 7.002e-05,
#    'open': 7.359e-05,
#    'time': 1514923200,
#    'volumefrom': 905140.18,
#    'volumeto': 65.18},
#   {'close': 7.55e-05,
#    'high': 7.652e-05,
#    'low': 7.384e-05,
#    'open': 7.429e-05,
#    'time': 1514926800,
#    'volumefrom': 350481.26,
#    'volumeto': 26.32},
#   {'close': 7.359e-05,
#    'high': 7.568e-05,
#    'low': 7.343e-05,
#    'open': 7.552e-05,
#    'time': 1514930400,
#    'volumefrom': 240700.88,
#    'volumeto': 17.83},
#   {'close': 7.388e-05,
#    'high': 7.553e-05,
#    'low': 7.278e-05,
#    'open': 7.361e-05,
#    'time': 1514934000,
#    'volumefrom': 451592.41,
#    'volumeto': 33.24},
#   {'close': 7.571e-05,
#    'high': 7.682e-05,
#    'low': 7.36e-05,
#    'open': 7.386e-05,
#    'time': 1514937600,
#    'volumefrom': 566637.04,
#    'volumeto': 43.11},
#   {'close': 7.516e-05,
#    'high': 7.666e-05,
#    'low': 7.486e-05,
#    'open': 7.571e-05,
#    'time': 1514941200,
#    'volumefrom': 297993.77,
#    'volumeto': 22.6},
#   {'close': 7.055e-05,
#    'high': 7.503e-05,
#    'low': 7.031e-05,
#    'open': 7.503e-05,
#    'time': 1514944800,
#    'volumefrom': 456807.62,
#    'volumeto': 33.03},
#   {'close': 7.2e-05,
#    'high': 7.259e-05,
#    'low': 7.006e-05,
#    'open': 7.035e-05,
#    'time': 1514948400,
#    'volumefrom': 405456.8,
#    'volumeto': 28.73},
#   {'close': 6.99e-05,
#    'high': 7.292e-05,
#    'low': 6.976e-05,
#    'open': 7.197e-05,
#    'time': 1514952000,
#    'volumefrom': 258782.78,
#    'volumeto': 18.41},
#   {'close': 7.098e-05,
#    'high': 7.176e-05,
#    'low': 6.971e-05,
#    'open': 6.971e-05,
#    'time': 1514955600,
#    'volumefrom': 231707.79,
#    'volumeto': 16.39},
#   {'close': 7.109e-05,
#    'high': 7.328e-05,
#    'low': 7.062e-05,
#    'open': 7.116e-05,
#    'time': 1514959200,
#    'volumefrom': 280581.17,
#    'volumeto': 20.23},
#   {'close': 7.227e-05,
#    'high': 7.291e-05,
#    'low': 7.098e-05,
#    'open': 7.098e-05,
#    'time': 1514962800,
#    'volumefrom': 173744.4,
#    'volumeto': 12.46},
#   {'close': 7.311e-05,
#    'high': 7.37e-05,
#    'low': 7.228e-05,
#    'open': 7.247e-05,
#    'time': 1514966400,
#    'volumefrom': 183015.28,
#    'volumeto': 13.39},
#   {'close': 7.404e-05,
#    'high': 7.601e-05,
#    'low': 7.299e-05,
#    'open': 7.311e-05,
#    'time': 1514970000,
#    'volumefrom': 447954.32,
#    'volumeto': 33.42},
#   {'close': 7.583e-05,
#    'high': 7.626e-05,
#    'low': 7.353e-05,
#    'open': 7.433e-05,
#    'time': 1514973600,
#    'volumefrom': 283638.55,
#    'volumeto': 21.24},
#   {'close': 7.497e-05,
#    'high': 7.614e-05,
#    'low': 7.422e-05,
#    'open': 7.614e-05,
#    'time': 1514977200,
#    'volumefrom': 139406.42,
#    'volumeto': 10.38},
#   {'close': 7.517e-05,
#    'high': 7.561e-05,
#    'low': 7.39e-05,
#    'open': 7.497e-05,
#    'time': 1514980800,
#    'volumefrom': 192632.47,
#    'volumeto': 14.37},
#   {'close': 7.594e-05,
#    'high': 7.599e-05,
#    'low': 7.478e-05,
#    'open': 7.516e-05,
#    'time': 1514984400,
#    'volumefrom': 160969.04,
#    'volumeto': 12.05},
#   {'close': 7.877e-05,
#    'high': 7.945e-05,
#    'low': 7.572e-05,
#    'open': 7.594e-05,
#    'time': 1514988000,
#    'volumefrom': 498878.82,
#    'volumeto': 38.77},
#   {'close': 7.662e-05,
#    'high': 7.901e-05,
#    'low': 7.635e-05,
#    'open': 7.85e-05,
#    'time': 1514991600,
#    'volumefrom': 247362.57,
#    'volumeto': 19.04},
#   {'close': 7.593e-05,
#    'high': 7.701e-05,
#    'low': 7.526e-05,
#    'open': 7.664e-05,
#    'time': 1514995200,
#    'volumefrom': 327194.4,
#    'volumeto': 24.74},
#   {'close': 7.548e-05,
#    'high': 7.677e-05,
#    'low': 7.496e-05,
#    'open': 7.573e-05,
#    'time': 1514998800,
#    'volumefrom': 230147.89,
#    'volumeto': 17.35},
#   {'close': 7.602e-05,
#    'high': 7.623e-05,
#    'low': 7.494e-05,
#    'open': 7.543e-05,
#    'time': 1515002400,
#    'volumefrom': 326671.97,
#    'volumeto': 24.69},
#   {'close': 7.708e-05,
#    'high': 7.73e-05,
#    'low': 7.399e-05,
#    'open': 7.603e-05,
#    'time': 1515006000,
#    'volumefrom': 365273.65,
#    'volumeto': 27.75},
#   {'close': 7.918e-05,
#    'high': 7.99e-05,
#    'low': 7.683e-05,
#    'open': 7.705e-05,
#    'time': 1515009600,
#    'volumefrom': 366531.41,
#    'volumeto': 28.82},
#   {'close': 7.804e-05,
#    'high': 7.917e-05,
#    'low': 7.73e-05,
#    'open': 7.911e-05,
#    'time': 1515013200,
#    'volumefrom': 339398.94,
#    'volumeto': 26.47},
#   {'close': 7.805e-05,
#    'high': 7.837e-05,
#    'low': 7.699e-05,
#    'open': 7.803e-05,
#    'time': 1515016800,
#    'volumefrom': 286386.1,
#    'volumeto': 22.19},
#   {'close': 7.724e-05,
#    'high': 7.809e-05,
#    'low': 7.691e-05,
#    'open': 7.806e-05,
#    'time': 1515020400,
#    'volumefrom': 251438.81,
#    'volumeto': 19.42},
#   {'close': 7.762e-05,
#    'high': 7.844e-05,
#    'low': 7.715e-05,
#    'open': 7.715e-05,
#    'time': 1515024000,
#    'volumefrom': 156107.93,
#    'volumeto': 12.15},
#   {'close': 7.531e-05,
#    'high': 7.801e-05,
#    'low': 7.46e-05,
#    'open': 7.775e-05,
#    'time': 1515027600,
#    'volumefrom': 350718.36,
#    'volumeto': 26.57},
#   {'close': 7.573e-05,
#    'high': 7.595e-05,
#    'low': 7.389e-05,
#    'open': 7.528e-05,
#    'time': 1515031200,
#    'volumefrom': 286191.2,
#    'volumeto': 21.4},
#   {'close': 7.473e-05,
#    'high': 7.63e-05,
#    'low': 7.305e-05,
#    'open': 7.587e-05,
#    'time': 1515034800,
#    'volumefrom': 156129.14,
#    'volumeto': 11.64},
#   {'close': 7.343e-05,
#    'high': 7.507e-05,
#    'low': 7.339e-05,
#    'open': 7.473e-05,
#    'time': 1515038400,
#    'volumefrom': 60053.35,
#    'volumeto': 4.5},
#   {'close': 7.364e-05,
#    'high': 7.39e-05,
#    'low': 6.936e-05,
#    'open': 7.26e-05,
#    'time': 1515042000,
#    'volumefrom': 104638.39,
#    'volumeto': 7.56},
#   {'close': 7.325e-05,
#    'high': 7.518e-05,
#    'low': 7.244e-05,
#    'open': 7.379e-05,
#    'time': 1515045600,
#    'volumefrom': 475946.15,
#    'volumeto': 34.62}],
#  'FirstValueInArray': True,
#  'Response': 'Success',
#  'TimeFrom': 1514757600,
#  'TimeTo': 1515045600,
#  'Type': 100}
